# %% [markdown]
# <h1 style="font-size:36px;">Multilayer Perceptron</h1>

# %% [markdown]
# MLP is a deep learning method that aims to learn complex relationships between data by using artificial neural network structure. The MLP model for Bitcoin price prediction attempts to predict future prices using historical price data. The model has a network structure consisting of many hidden layers, and nodes in each layer generate an output using inputs from all nodes in the previous layer. The accuracy of the model depends on many factors such as the learning rate, parameter settings, and the features used.
#
# MLP, yapay sinir ağı yapısını kullanarak, veriler arasındaki kompleks ilişkileri öğrenmeyi amaçlayan bir derin öğrenme yöntemidir. Bitcoin fiyat tahmini yapmak için kullanılan MLP modeli, tarihsel fiyat verilerini kullanarak gelecekteki fiyatları tahmin etmeye çalışır. Model, birçok gizli katmandan oluşan bir ağ yapısına sahiptir ve her katmandaki düğümler, önceki katmandaki tüm düğümlerden gelen girdileri kullanarak bir çıkış üretir. Modelin doğruluğu, öğrenme oranı, parametre ayarları ve kullanılan özellikler gibi birçok faktöre bağlıdır.

# %% [markdown]
# This model includes two dense layers. The first layer has 100 output neurons. The second layer has only one output neuron. The total number of parameters is 4201 and the number of trainable parameters is also 4201. This model can be used for regression problems and the output of the model is a number.
#
# Bu model, iki adet yoğun katman içerir. İlk katman,  100 adet çıktı nöronuna sahiptir. İkinci katman,  sadece bir adet çıktı nöronuna sahiptir. Toplam parametre sayısı 4201'dir ve eğitilebilir parametre sayısı da 4201'dir. Bu model, regresyon problemleri için kullanılabilir ve modelin çıkışı bir sayıdır.

# %% [markdown]
# <h3 style="font-size:24px;">Data preprocessing and Preparation</h3>

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras import models,layers,optimizers,callbacks
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('btcusd.csv',usecols=['Open','High','Low','Close','Date'])
df.Date = pd.to_datetime(df.Date, format="%Y-%m-%d")
df.set_index('Date',inplace=True)
print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3163 entries, 2014-09-17 to 2023-05-15
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3163 non-null   float64
#  1   High    3163 non-null   float64
#  2   Low     3163 non-null   float64
#  3   Close   3163 non-null   float64
# dtypes: float64(4)
# memory usage: 123.6 KB
# None
#                     Open          High           Low         Close
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-05-11  27621.085938  27621.941406  26781.826172  27000.789063
# 2023-05-12  26987.662109  27055.646484  25878.429688  26804.990234
# 2023-05-13  26807.769531  27030.482422  26710.873047  26784.078125
# 2023-05-14  26788.974609  27150.976563  26661.355469  26930.638672
# 2023-05-15  26939.564453  27516.851563  26770.279297  27406.390625
#
# [3163 rows x 4 columns]

# %%
plt.figure(figsize=(20,10))
df = df['2018':]
plt.plot(df.index, df["Close"])
plt.xticks(df[::90].index, df[::90].index.date,rotation = -46)
plt.title("BTC stock price over time")
plt.xlabel("time")
plt.ylabel("price")
plt.show()

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
train_data, test_data = train_test_split(df,random_state=42,test_size=0.2,shuffle=False) 
window_size = 40
X_train, y_train = split_sequence(train_data["Close"].values, window_size)
X_test, y_test = split_sequence(test_data["Close"].values, window_size)

# %% [markdown]
# # MLP Model

# %%
network = models.Sequential([
  layers.Dense(60, activation='relu', input_dim=window_size),  
  layers.Dense(1)
])
# network.compile(optimizer=optimizers.Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy']) #loss='mse
network.compile(optimizer=optimizers.Adam(learning_rate=0.003),loss='mse',metrics=['accuracy']) 
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 60)                2460
#
#  dense_1 (Dense)             (None, 1)                 61
#
# =================================================================
# Total params: 2,521
# Trainable params: 2,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
cb = callbacks.TensorBoard()
trained_network=network.fit(X_train, y_train, epochs=50, batch_size=32,verbose=1,callbacks=[cb],validation_split=0.16,shuffle=False)
# Out:
# Epoch 1/50
# 41/41 [==============================] - 0s 3ms/step - loss: 9536241.0000 - accuracy: 0.0000e+00 - val_loss: 42439796.0000 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 41/41 [==============================] - 0s 1ms/step - loss: 6960290.0000 - accuracy: 0.0000e+00 - val_loss: 144280464.0000 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 41/41 [==============================] - 0s 989us/step - loss: 10199784.0000 - accuracy: 0.0000e+00 - val_loss: 208905744.0000 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 41/41 [==============================] - 0s 994us/step - loss: 16039104.0000 - accuracy: 0.0000e+00 - val_loss: 296708000.0000 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 41/41 [==============================] - 0s 1ms/step - loss: 45066380.0000 - accuracy: 0.0000e+00 - val_loss: 38899772.0000 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 41/41 [==============================] - 0s 1000us/step - loss: 83122120.0000 - accuracy: 0.0000e+00 - val_loss: 270593824.0000 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 41/41 [==============================] - 0s 981us/step - loss: 11957826.0000 - accuracy: 0.0000e+00 - val_loss: 119955520.0000 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 41/41 [==============================] - 0s 980us/step - loss: 4932590.0000 - accuracy: 0.0000e+00 - val_loss: 44363472.0000 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 41/41 [==============================] - 0s 1ms/step - loss: 4021707.2500 - accuracy: 0.0000e+00 - val_loss: 26004562.0000 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3414439.0000 - accuracy: 0.0000e+00 - val_loss: 14329771.0000 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 41/41 [==============================] - 0s 995us/step - loss: 3242541.0000 - accuracy: 0.0000e+00 - val_loss: 11566245.0000 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3063217.0000 - accuracy: 0.0000e+00 - val_loss: 9783552.0000 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 41/41 [==============================] - 0s 1ms/step - loss: 2998207.0000 - accuracy: 0.0000e+00 - val_loss: 9050052.0000 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 41/41 [==============================] - 0s 996us/step - loss: 2964050.2500 - accuracy: 0.0000e+00 - val_loss: 8520905.0000 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 41/41 [==============================] - 0s 986us/step - loss: 2952166.5000 - accuracy: 0.0000e+00 - val_loss: 8146380.5000 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 41/41 [==============================] - 0s 1ms/step - loss: 2957584.5000 - accuracy: 0.0000e+00 - val_loss: 7726189.5000 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 41/41 [==============================] - 0s 1ms/step - loss: 2918360.5000 - accuracy: 0.0000e+00 - val_loss: 7266418.0000 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 41/41 [==============================] - 0s 1ms/step - loss: 2909716.2500 - accuracy: 0.0000e+00 - val_loss: 6829614.5000 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 41/41 [==============================] - 0s 993us/step - loss: 2960007.5000 - accuracy: 0.0000e+00 - val_loss: 6609624.5000 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3012219.0000 - accuracy: 0.0000e+00 - val_loss: 6385370.5000 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3064734.7500 - accuracy: 0.0000e+00 - val_loss: 6256191.5000 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 41/41 [==============================] - 0s 986us/step - loss: 3038019.0000 - accuracy: 0.0000e+00 - val_loss: 5942689.5000 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3090826.2500 - accuracy: 0.0000e+00 - val_loss: 5794218.5000 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3183526.5000 - accuracy: 0.0000e+00 - val_loss: 5669651.5000 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 41/41 [==============================] - 0s 992us/step - loss: 3230613.0000 - accuracy: 0.0000e+00 - val_loss: 5537381.0000 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3365094.2500 - accuracy: 0.0000e+00 - val_loss: 5440386.5000 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3482438.7500 - accuracy: 0.0000e+00 - val_loss: 5398538.5000 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3518927.7500 - accuracy: 0.0000e+00 - val_loss: 5336636.5000 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 41/41 [==============================] - 0s 993us/step - loss: 3501600.7500 - accuracy: 0.0000e+00 - val_loss: 5306160.5000 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3500135.0000 - accuracy: 0.0000e+00 - val_loss: 5220602.5000 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3485655.2500 - accuracy: 0.0000e+00 - val_loss: 5200009.5000 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3485796.2500 - accuracy: 0.0000e+00 - val_loss: 5132988.0000 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3484568.2500 - accuracy: 0.0000e+00 - val_loss: 5099862.5000 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3505686.0000 - accuracy: 0.0000e+00 - val_loss: 5058944.5000 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3472687.7500 - accuracy: 0.0000e+00 - val_loss: 5047905.5000 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3469901.7500 - accuracy: 0.0000e+00 - val_loss: 5019820.0000 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3492377.2500 - accuracy: 0.0000e+00 - val_loss: 5083192.0000 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 41/41 [==============================] - 0s 1ms/step - loss: 3545149.5000 - accuracy: 0.0000e+00 - val_loss: 5166721.5000 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 41/41 [==============================] - 0s 996us/step - loss: 3506945.0000 - accuracy: 0.0000e+00 - val_loss: 5382144.0000 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 41/41 [==============================] - 0s 993us/step - loss: 3450058.0000 - accuracy: 0.0000e+00 - val_loss: 5555633.5000 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 41/41 [==============================] - 0s 993us/step - loss: 3135822.0000 - accuracy: 0.0000e+00 - val_loss: 5530287.5000 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 41/41 [==============================] - 0s 991us/step - loss: 2746752.0000 - accuracy: 0.0000e+00 - val_loss: 5295063.0000 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 41/41 [==============================] - 0s 992us/step - loss: 2512112.7500 - accuracy: 0.0000e+00 - val_loss: 4949805.0000 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 41/41 [==============================] - 0s 991us/step - loss: 2629908.0000 - accuracy: 0.0000e+00 - val_loss: 4836591.5000 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 41/41 [==============================] - 0s 986us/step - loss: 2831240.5000 - accuracy: 0.0000e+00 - val_loss: 4801572.5000 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 41/41 [==============================] - 0s 991us/step - loss: 3073367.5000 - accuracy: 0.0000e+00 - val_loss: 4791400.0000 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 41/41 [==============================] - 0s 977us/step - loss: 3168605.7500 - accuracy: 0.0000e+00 - val_loss: 5008757.0000 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 41/41 [==============================] - 0s 985us/step - loss: 3124003.0000 - accuracy: 0.0000e+00 - val_loss: 4855495.0000 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 41/41 [==============================] - 0s 975us/step - loss: 3051557.0000 - accuracy: 0.0000e+00 - val_loss: 5111670.0000 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 41/41 [==============================] - 0s 993us/step - loss: 2852998.0000 - accuracy: 0.0000e+00 - val_loss: 4891476.5000 - val_accuracy: 0.0000e+00

# %%
y_predicted = network.predict(X_test, verbose=1)
result = test_data.iloc[window_size:]
result['Predicted'] = y_predicted
result[['Close','Predicted']]
# Out:
# 12/12 [==============================] - 0s 524us/step
# <ipython-input-8-f75e88b767c6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['Predicted'] = y_predicted
#                    Close     Predicted
# Date
# 2022-05-28  28814.900391  28610.224609
# 2022-05-29  29445.957031  28517.533203
# 2022-05-30  31726.390625  29220.158203
# 2022-05-31  31792.310547  28897.925781
# 2022-06-01  29799.080078  29777.111328
# ...                  ...           ...
# 2023-05-11  27000.789063  27679.880859
# 2023-05-12  26804.990234  27030.011719
# 2023-05-13  26784.078125  26398.076172
# 2023-05-14  26930.638672  26303.716797
# 2023-05-15  27406.390625  26044.904297
#
# [353 rows x 2 columns]

# %%
test_set_range = result.index
plt.figure(figsize=(20,10))
plt.plot(test_set_range, result['Predicted'], color='blue', marker='o', linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range, result['Close'], color='red', label='Actual Price')
plt.title('BTC Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

MSE = mean_squared_error(result['Close'], result['Predicted'])
RMSE = mean_squared_error(result['Close'], result['Predicted'], squared=False)
MAE = mean_absolute_error(result['Close'], result['Predicted'])
R2 = r2_score(result['Close'], result['Predicted'])

# %%
import pandas as pd

# Değerleri bir sözlük yapısında sakla
results = {'MSE': [MSE], 'RMSE': [RMSE], 'MAE': [MAE], 'R2': [R2]}

# DataFrame oluştur ve index değerlerini varsayılan değerlerle ata
MLP_ERROR= pd.DataFrame.from_dict(results, orient='index').T

# DataFrame'i ERROR ismiyle kaydet
MLP_ERROR = MLP_ERROR.to_string(index=False)

# ERROR'u yazdır

print(MLP_ERROR)
# Out:
#          MSE        RMSE        MAE       R2
# 1.166463e+06 1080.029138 753.688031 0.930574

# %%
import pandas as pd

# Değerleri bir sözlük yapısında sakla
results = {'MSE': [MSE], 'RMSE': [RMSE], 'MAE': [MAE], 'R2': [R2]}

# DataFrame oluştur ve index değerlerini varsayılan değerlerle ata
MLP2_ERROR = pd.DataFrame.from_dict(results, orient='index').T

# Çıktıyı metin dosyasına aktar
output_text = MLP2_ERROR.to_string(index=False)

# Metin dosyasını kaydet
with open('MLP2_ERROR.txt', 'w') as file:
    file.write(output_text)

# %%
import matplotlib.pyplot as plt


# Eğitim ve doğrulama loss değerlerini alırız
train_loss = trained_network.history['loss']
val_loss = trained_network.history['val_loss']

# Epoch sayısını alırız
epochs = range(1, len(train_loss) + 1)

# Grafiği oluştururuz
plt.plot(epochs, train_loss, 'b', label='Eğitim Loss')
plt.plot(epochs, val_loss, 'r', label='Doğrulama Loss')
plt.title('Eğitim ve Doğrulama Loss Değerleri')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
