# %% [markdown]
# <h1 style="font-size:36px;">Multilayer Perceptron</h1>

# %% [markdown]
# MLP is a deep learning method that aims to learn complex relationships between data by using artificial neural network structure. The MLP model for Bitcoin price prediction attempts to predict future prices using historical price data. The model has a network structure consisting of many hidden layers, and nodes in each layer generate an output using inputs from all nodes in the previous layer. The accuracy of the model depends on many factors such as the learning rate, parameter settings, and the features used.
#
# MLP, yapay sinir ağı yapısını kullanarak, veriler arasındaki kompleks ilişkileri öğrenmeyi amaçlayan bir derin öğrenme yöntemidir. Bitcoin fiyat tahmini yapmak için kullanılan MLP modeli, tarihsel fiyat verilerini kullanarak gelecekteki fiyatları tahmin etmeye çalışır. Model, birçok gizli katmandan oluşan bir ağ yapısına sahiptir ve her katmandaki düğümler, önceki katmandaki tüm düğümlerden gelen girdileri kullanarak bir çıkış üretir. Modelin doğruluğu, öğrenme oranı, parametre ayarları ve kullanılan özellikler gibi birçok faktöre bağlıdır.

# %% [markdown]
# <h1 style="font-size:15px;">Summary of the Model</h1>

# %% [markdown]
# Optimizer: Adam
# Learning rate: 0.001
# Loss: Mse
# Metrics: Accuracy

# %%
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               4100
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 4,201
# Trainable params: 4,201
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# This model includes two dense layers. The first layer has 100 output neurons. The second layer has only one output neuron. The total number of parameters is 4201 and the number of trainable parameters is also 4201. This model can be used for regression problems and the output of the model is a number.
#
# Bu model, iki adet yoğun katman içerir. İlk katman,  100 adet çıktı nöronuna sahiptir. İkinci katman,  sadece bir adet çıktı nöronuna sahiptir. Toplam parametre sayısı 4201'dir ve eğitilebilir parametre sayısı da 4201'dir. Bu model, regresyon problemleri için kullanılabilir ve modelin çıkışı bir sayıdır.

# %% [markdown]
# <h1 style="font-size:15px;">Model Outputs</h1>

# %%
print(MLP_ERROR)
# Out:
#          MSE        RMSE         MAE       R2
# 2.715959e+06 1648.016588 1460.566791 0.842159

# %% [markdown]
# <h3 style="font-size:24px;">Data preprocessing and Preparation</h3>

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras import models,layers,optimizers,callbacks
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('btcusd.csv',usecols=['Open','High','Low','Close','Date'])
df.Date = pd.to_datetime(df.Date, format="%Y-%m-%d")
df.set_index('Date',inplace=True)
print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3150 entries, 2014-09-17 to 2023-05-02
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3150 non-null   float64
#  1   High    3150 non-null   float64
#  2   Low     3150 non-null   float64
#  3   Close   3150 non-null   float64
# dtypes: float64(4)
# memory usage: 123.0 KB
# None
#                     Open          High           Low         Close
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-04-28  29481.013672  29572.791016  28929.609375  29340.261719
# 2023-04-29  29336.566406  29452.455078  29088.042969  29248.488281
# 2023-04-30  29245.515625  29952.029297  29114.021484  29268.806641
# 2023-05-01  29227.103516  29329.935547  27680.792969  28091.568359
# 2023-05-02  28011.582031  28852.992188  27928.583984  28676.791016
#
# [3150 rows x 4 columns]

# %%
plt.figure(figsize=(20,10))
df = df['2018':]
plt.plot(df.index, df["Close"])
plt.xticks(df[::90].index, df[::90].index.date,rotation = -46)
plt.title("BTC stock price over time")
plt.xlabel("time")
plt.ylabel("price")
plt.show()

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
train_data, test_data = train_test_split(df,random_state=42,test_size=0.2,shuffle=False) 
window_size = 40
X_train, y_train = split_sequence(train_data["Close"].values, window_size)
X_test, y_test = split_sequence(test_data["Close"].values, window_size)

# %% [markdown]
# # MLP Model

# %%
network = models.Sequential([
  layers.Dense(100, activation='relu', input_dim=window_size),  
  layers.Dense(1)
])
# network.compile(optimizer=optimizers.Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy']) #loss='mse
network.compile(optimizer=optimizers.Adam(learning_rate=0.001),loss='mse',metrics=['accuracy']) 
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               4100
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 4,201
# Trainable params: 4,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
cb = callbacks.TensorBoard()
trained_network=network.fit(X_train, y_train, epochs=200, batch_size=64,verbose=1,callbacks=[cb],validation_split=0.16,shuffle=False)
# Out:
# Epoch 1/200
# 20/20 [==============================] - 0s 6ms/step - loss: 22021210.0000 - accuracy: 0.0000e+00 - val_loss: 49764456.0000 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 20/20 [==============================] - 0s 2ms/step - loss: 112852096.0000 - accuracy: 0.0000e+00 - val_loss: 23671846.0000 - val_accuracy: 0.0000e+00
# Epoch 3/200
# 20/20 [==============================] - 0s 2ms/step - loss: 378292448.0000 - accuracy: 0.0000e+00 - val_loss: 825336896.0000 - val_accuracy: 0.0000e+00
# Epoch 4/200
# 20/20 [==============================] - 0s 2ms/step - loss: 222949360.0000 - accuracy: 0.0000e+00 - val_loss: 716477184.0000 - val_accuracy: 0.0000e+00
# Epoch 5/200
# 20/20 [==============================] - 0s 2ms/step - loss: 30668226.0000 - accuracy: 0.0000e+00 - val_loss: 121144304.0000 - val_accuracy: 0.0000e+00
# Epoch 6/200
# 20/20 [==============================] - 0s 2ms/step - loss: 8567867.0000 - accuracy: 0.0000e+00 - val_loss: 20836352.0000 - val_accuracy: 0.0000e+00
# Epoch 7/200
# 20/20 [==============================] - 0s 2ms/step - loss: 7523802.5000 - accuracy: 0.0000e+00 - val_loss: 19585882.0000 - val_accuracy: 0.0000e+00
# Epoch 8/200
# 20/20 [==============================] - 0s 2ms/step - loss: 7312856.0000 - accuracy: 0.0000e+00 - val_loss: 19917310.0000 - val_accuracy: 0.0000e+00
# Epoch 9/200
# 20/20 [==============================] - 0s 2ms/step - loss: 7259883.5000 - accuracy: 0.0000e+00 - val_loss: 18786228.0000 - val_accuracy: 0.0000e+00
# Epoch 10/200
# 20/20 [==============================] - 0s 2ms/step - loss: 7052361.0000 - accuracy: 0.0000e+00 - val_loss: 18898432.0000 - val_accuracy: 0.0000e+00
# Epoch 11/200
# 20/20 [==============================] - 0s 2ms/step - loss: 6983525.0000 - accuracy: 0.0000e+00 - val_loss: 18098824.0000 - val_accuracy: 0.0000e+00
# Epoch 12/200
# 20/20 [==============================] - 0s 2ms/step - loss: 6798057.5000 - accuracy: 0.0000e+00 - val_loss: 18076714.0000 - val_accuracy: 0.0000e+00
# Epoch 13/200
# 20/20 [==============================] - 0s 2ms/step - loss: 6734039.0000 - accuracy: 0.0000e+00 - val_loss: 17353296.0000 - val_accuracy: 0.0000e+00
# Epoch 14/200
# 20/20 [==============================] - 0s 2ms/step - loss: 6543752.5000 - accuracy: 0.0000e+00 - val_loss: 17348466.0000 - val_accuracy: 0.0000e+00
# Epoch 15/200
# 20/20 [==============================] - 0s 2ms/step - loss: 6508765.0000 - accuracy: 0.0000e+00 - val_loss: 16586582.0000 - val_accuracy: 0.0000e+00
# Epoch 16/200
# 20/20 [==============================] - 0s 2ms/step - loss: 6294806.5000 - accuracy: 0.0000e+00 - val_loss: 16727446.0000 - val_accuracy: 0.0000e+00
# Epoch 17/200
# 20/20 [==============================] - 0s 2ms/step - loss: 6347955.0000 - accuracy: 0.0000e+00 - val_loss: 15816193.0000 - val_accuracy: 0.0000e+00
# Epoch 18/200
# 20/20 [==============================] - 0s 2ms/step - loss: 6097693.0000 - accuracy: 0.0000e+00 - val_loss: 16358546.0000 - val_accuracy: 0.0000e+00
# Epoch 19/200
# 20/20 [==============================] - 0s 2ms/step - loss: 6472533.0000 - accuracy: 0.0000e+00 - val_loss: 15086292.0000 - val_accuracy: 0.0000e+00
# Epoch 20/200
# 20/20 [==============================] - 0s 2ms/step - loss: 6422549.5000 - accuracy: 0.0000e+00 - val_loss: 16567392.0000 - val_accuracy: 0.0000e+00
# Epoch 21/200
# 20/20 [==============================] - 0s 2ms/step - loss: 8541325.0000 - accuracy: 0.0000e+00 - val_loss: 14484980.0000 - val_accuracy: 0.0000e+00
# Epoch 22/200
# 20/20 [==============================] - 0s 2ms/step - loss: 11809929.0000 - accuracy: 0.0000e+00 - val_loss: 19560722.0000 - val_accuracy: 0.0000e+00
# Epoch 23/200
# 20/20 [==============================] - 0s 1ms/step - loss: 27243774.0000 - accuracy: 0.0000e+00 - val_loss: 18951458.0000 - val_accuracy: 0.0000e+00
# Epoch 24/200
# 20/20 [==============================] - 0s 2ms/step - loss: 62355320.0000 - accuracy: 0.0000e+00 - val_loss: 52697152.0000 - val_accuracy: 0.0000e+00
# Epoch 25/200
# 20/20 [==============================] - 0s 2ms/step - loss: 158481104.0000 - accuracy: 0.0000e+00 - val_loss: 166795744.0000 - val_accuracy: 0.0000e+00
# Epoch 26/200
# 20/20 [==============================] - 0s 2ms/step - loss: 243279216.0000 - accuracy: 0.0000e+00 - val_loss: 405168736.0000 - val_accuracy: 0.0000e+00
# Epoch 27/200
# 20/20 [==============================] - 0s 2ms/step - loss: 255820064.0000 - accuracy: 0.0000e+00 - val_loss: 668084032.0000 - val_accuracy: 0.0000e+00
# Epoch 28/200
# 20/20 [==============================] - 0s 2ms/step - loss: 87902064.0000 - accuracy: 0.0000e+00 - val_loss: 281006368.0000 - val_accuracy: 0.0000e+00
# Epoch 29/200
# 20/20 [==============================] - 0s 2ms/step - loss: 24926758.0000 - accuracy: 0.0000e+00 - val_loss: 73580576.0000 - val_accuracy: 0.0000e+00
# Epoch 30/200
# 20/20 [==============================] - 0s 2ms/step - loss: 7268821.0000 - accuracy: 0.0000e+00 - val_loss: 24648166.0000 - val_accuracy: 0.0000e+00
# Epoch 31/200
# 20/20 [==============================] - 0s 2ms/step - loss: 5580625.5000 - accuracy: 0.0000e+00 - val_loss: 15151479.0000 - val_accuracy: 0.0000e+00
# Epoch 32/200
# 20/20 [==============================] - 0s 2ms/step - loss: 5374824.0000 - accuracy: 0.0000e+00 - val_loss: 15174794.0000 - val_accuracy: 0.0000e+00
# Epoch 33/200
# 20/20 [==============================] - 0s 2ms/step - loss: 5304745.5000 - accuracy: 0.0000e+00 - val_loss: 14959754.0000 - val_accuracy: 0.0000e+00
# Epoch 34/200
# 20/20 [==============================] - 0s 2ms/step - loss: 5243697.0000 - accuracy: 0.0000e+00 - val_loss: 14691122.0000 - val_accuracy: 0.0000e+00
# Epoch 35/200
# 20/20 [==============================] - 0s 2ms/step - loss: 5173628.0000 - accuracy: 0.0000e+00 - val_loss: 14534169.0000 - val_accuracy: 0.0000e+00
# Epoch 36/200
# 20/20 [==============================] - 0s 1ms/step - loss: 5110613.0000 - accuracy: 0.0000e+00 - val_loss: 14310858.0000 - val_accuracy: 0.0000e+00
# Epoch 37/200
# 20/20 [==============================] - 0s 2ms/step - loss: 5045469.5000 - accuracy: 0.0000e+00 - val_loss: 14129385.0000 - val_accuracy: 0.0000e+00
# Epoch 38/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4983179.0000 - accuracy: 0.0000e+00 - val_loss: 13932596.0000 - val_accuracy: 0.0000e+00
# Epoch 39/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4920925.0000 - accuracy: 0.0000e+00 - val_loss: 13751636.0000 - val_accuracy: 0.0000e+00
# Epoch 40/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4860188.5000 - accuracy: 0.0000e+00 - val_loss: 13568493.0000 - val_accuracy: 0.0000e+00
# Epoch 41/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4800085.5000 - accuracy: 0.0000e+00 - val_loss: 13394293.0000 - val_accuracy: 0.0000e+00
# Epoch 42/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4740876.0000 - accuracy: 0.0000e+00 - val_loss: 13220714.0000 - val_accuracy: 0.0000e+00
# Epoch 43/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4682552.5000 - accuracy: 0.0000e+00 - val_loss: 13054945.0000 - val_accuracy: 0.0000e+00
# Epoch 44/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4625740.0000 - accuracy: 0.0000e+00 - val_loss: 12891392.0000 - val_accuracy: 0.0000e+00
# Epoch 45/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4570429.0000 - accuracy: 0.0000e+00 - val_loss: 12733917.0000 - val_accuracy: 0.0000e+00
# Epoch 46/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4516494.0000 - accuracy: 0.0000e+00 - val_loss: 12579480.0000 - val_accuracy: 0.0000e+00
# Epoch 47/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4463672.0000 - accuracy: 0.0000e+00 - val_loss: 12430719.0000 - val_accuracy: 0.0000e+00
# Epoch 48/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4412248.5000 - accuracy: 0.0000e+00 - val_loss: 12286300.0000 - val_accuracy: 0.0000e+00
# Epoch 49/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4362098.0000 - accuracy: 0.0000e+00 - val_loss: 12147581.0000 - val_accuracy: 0.0000e+00
# Epoch 50/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4313397.5000 - accuracy: 0.0000e+00 - val_loss: 12013287.0000 - val_accuracy: 0.0000e+00
# Epoch 51/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4266004.5000 - accuracy: 0.0000e+00 - val_loss: 11883306.0000 - val_accuracy: 0.0000e+00
# Epoch 52/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4219788.5000 - accuracy: 0.0000e+00 - val_loss: 11757592.0000 - val_accuracy: 0.0000e+00
# Epoch 53/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4174778.2500 - accuracy: 0.0000e+00 - val_loss: 11635841.0000 - val_accuracy: 0.0000e+00
# Epoch 54/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4130832.0000 - accuracy: 0.0000e+00 - val_loss: 11517754.0000 - val_accuracy: 0.0000e+00
# Epoch 55/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4087883.5000 - accuracy: 0.0000e+00 - val_loss: 11403611.0000 - val_accuracy: 0.0000e+00
# Epoch 56/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4045888.2500 - accuracy: 0.0000e+00 - val_loss: 11292502.0000 - val_accuracy: 0.0000e+00
# Epoch 57/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4004836.0000 - accuracy: 0.0000e+00 - val_loss: 11185270.0000 - val_accuracy: 0.0000e+00
# Epoch 58/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3964853.7500 - accuracy: 0.0000e+00 - val_loss: 11080629.0000 - val_accuracy: 0.0000e+00
# Epoch 59/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3925673.0000 - accuracy: 0.0000e+00 - val_loss: 10980095.0000 - val_accuracy: 0.0000e+00
# Epoch 60/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3887451.2500 - accuracy: 0.0000e+00 - val_loss: 10881561.0000 - val_accuracy: 0.0000e+00
# Epoch 61/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3849889.7500 - accuracy: 0.0000e+00 - val_loss: 10787022.0000 - val_accuracy: 0.0000e+00
# Epoch 62/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3813273.2500 - accuracy: 0.0000e+00 - val_loss: 10693879.0000 - val_accuracy: 0.0000e+00
# Epoch 63/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3777137.7500 - accuracy: 0.0000e+00 - val_loss: 10605203.0000 - val_accuracy: 0.0000e+00
# Epoch 64/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3742089.2500 - accuracy: 0.0000e+00 - val_loss: 10516567.0000 - val_accuracy: 0.0000e+00
# Epoch 65/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3707374.0000 - accuracy: 0.0000e+00 - val_loss: 10433768.0000 - val_accuracy: 0.0000e+00
# Epoch 66/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3674007.2500 - accuracy: 0.0000e+00 - val_loss: 10348589.0000 - val_accuracy: 0.0000e+00
# Epoch 67/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3640328.5000 - accuracy: 0.0000e+00 - val_loss: 10272378.0000 - val_accuracy: 0.0000e+00
# Epoch 68/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3608656.2500 - accuracy: 0.0000e+00 - val_loss: 10188461.0000 - val_accuracy: 0.0000e+00
# Epoch 69/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3575635.0000 - accuracy: 0.0000e+00 - val_loss: 10120968.0000 - val_accuracy: 0.0000e+00
# Epoch 70/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3546574.5000 - accuracy: 0.0000e+00 - val_loss: 10033912.0000 - val_accuracy: 0.0000e+00
# Epoch 71/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3513482.2500 - accuracy: 0.0000e+00 - val_loss: 9981082.0000 - val_accuracy: 0.0000e+00
# Epoch 72/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3489702.0000 - accuracy: 0.0000e+00 - val_loss: 9880981.0000 - val_accuracy: 0.0000e+00
# Epoch 73/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3456908.7500 - accuracy: 0.0000e+00 - val_loss: 9860604.0000 - val_accuracy: 0.0000e+00
# Epoch 74/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3452916.7500 - accuracy: 0.0000e+00 - val_loss: 9723823.0000 - val_accuracy: 0.0000e+00
# Epoch 75/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3442359.5000 - accuracy: 0.0000e+00 - val_loss: 9790764.0000 - val_accuracy: 0.0000e+00
# Epoch 76/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3568718.2500 - accuracy: 0.0000e+00 - val_loss: 9570460.0000 - val_accuracy: 0.0000e+00
# Epoch 77/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3858349.0000 - accuracy: 0.0000e+00 - val_loss: 9928493.0000 - val_accuracy: 0.0000e+00
# Epoch 78/200
# 20/20 [==============================] - 0s 2ms/step - loss: 5157707.5000 - accuracy: 0.0000e+00 - val_loss: 9676065.0000 - val_accuracy: 0.0000e+00
# Epoch 79/200
# 20/20 [==============================] - 0s 2ms/step - loss: 8897155.0000 - accuracy: 0.0000e+00 - val_loss: 11331874.0000 - val_accuracy: 0.0000e+00
# Epoch 80/200
# 20/20 [==============================] - 0s 1ms/step - loss: 22681172.0000 - accuracy: 0.0000e+00 - val_loss: 14433280.0000 - val_accuracy: 0.0000e+00
# Epoch 81/200
# 20/20 [==============================] - 0s 2ms/step - loss: 62410788.0000 - accuracy: 0.0000e+00 - val_loss: 29505990.0000 - val_accuracy: 0.0000e+00
# Epoch 82/200
# 20/20 [==============================] - 0s 2ms/step - loss: 184285120.0000 - accuracy: 0.0000e+00 - val_loss: 226714464.0000 - val_accuracy: 0.0000e+00
# Epoch 83/200
# 20/20 [==============================] - 0s 1ms/step - loss: 257080720.0000 - accuracy: 0.0000e+00 - val_loss: 413721760.0000 - val_accuracy: 0.0000e+00
# Epoch 84/200
# 20/20 [==============================] - 0s 1ms/step - loss: 210706352.0000 - accuracy: 0.0000e+00 - val_loss: 706340736.0000 - val_accuracy: 0.0000e+00
# Epoch 85/200
# 20/20 [==============================] - 0s 1ms/step - loss: 19517510.0000 - accuracy: 0.0000e+00 - val_loss: 76033192.0000 - val_accuracy: 0.0000e+00
# Epoch 86/200
# 20/20 [==============================] - 0s 2ms/step - loss: 5370334.0000 - accuracy: 0.0000e+00 - val_loss: 14587892.0000 - val_accuracy: 0.0000e+00
# Epoch 87/200
# 20/20 [==============================] - 0s 2ms/step - loss: 5251195.0000 - accuracy: 0.0000e+00 - val_loss: 14561550.0000 - val_accuracy: 0.0000e+00
# Epoch 88/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4962187.0000 - accuracy: 0.0000e+00 - val_loss: 14789107.0000 - val_accuracy: 0.0000e+00
# Epoch 89/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4898222.5000 - accuracy: 0.0000e+00 - val_loss: 14210996.0000 - val_accuracy: 0.0000e+00
# Epoch 90/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4847035.5000 - accuracy: 0.0000e+00 - val_loss: 14061489.0000 - val_accuracy: 0.0000e+00
# Epoch 91/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4794601.0000 - accuracy: 0.0000e+00 - val_loss: 13937861.0000 - val_accuracy: 0.0000e+00
# Epoch 92/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4745799.5000 - accuracy: 0.0000e+00 - val_loss: 13768512.0000 - val_accuracy: 0.0000e+00
# Epoch 93/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4696756.0000 - accuracy: 0.0000e+00 - val_loss: 13621000.0000 - val_accuracy: 0.0000e+00
# Epoch 94/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4648531.0000 - accuracy: 0.0000e+00 - val_loss: 13473244.0000 - val_accuracy: 0.0000e+00
# Epoch 95/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4601084.0000 - accuracy: 0.0000e+00 - val_loss: 13327234.0000 - val_accuracy: 0.0000e+00
# Epoch 96/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4554385.5000 - accuracy: 0.0000e+00 - val_loss: 13184780.0000 - val_accuracy: 0.0000e+00
# Epoch 97/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4508471.0000 - accuracy: 0.0000e+00 - val_loss: 13044827.0000 - val_accuracy: 0.0000e+00
# Epoch 98/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4463310.0000 - accuracy: 0.0000e+00 - val_loss: 12907718.0000 - val_accuracy: 0.0000e+00
# Epoch 99/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4418831.5000 - accuracy: 0.0000e+00 - val_loss: 12773455.0000 - val_accuracy: 0.0000e+00
# Epoch 100/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4375098.0000 - accuracy: 0.0000e+00 - val_loss: 12641932.0000 - val_accuracy: 0.0000e+00
# Epoch 101/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4332031.5000 - accuracy: 0.0000e+00 - val_loss: 12513065.0000 - val_accuracy: 0.0000e+00
# Epoch 102/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4289625.5000 - accuracy: 0.0000e+00 - val_loss: 12386866.0000 - val_accuracy: 0.0000e+00
# Epoch 103/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4247906.0000 - accuracy: 0.0000e+00 - val_loss: 12263372.0000 - val_accuracy: 0.0000e+00
# Epoch 104/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4206881.5000 - accuracy: 0.0000e+00 - val_loss: 12142475.0000 - val_accuracy: 0.0000e+00
# Epoch 105/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4166543.2500 - accuracy: 0.0000e+00 - val_loss: 12024182.0000 - val_accuracy: 0.0000e+00
# Epoch 106/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4126882.2500 - accuracy: 0.0000e+00 - val_loss: 11908459.0000 - val_accuracy: 0.0000e+00
# Epoch 107/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4087929.7500 - accuracy: 0.0000e+00 - val_loss: 11795153.0000 - val_accuracy: 0.0000e+00
# Epoch 108/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4049635.0000 - accuracy: 0.0000e+00 - val_loss: 11684592.0000 - val_accuracy: 0.0000e+00
# Epoch 109/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4012020.0000 - accuracy: 0.0000e+00 - val_loss: 11576782.0000 - val_accuracy: 0.0000e+00
# Epoch 110/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3975025.7500 - accuracy: 0.0000e+00 - val_loss: 11471472.0000 - val_accuracy: 0.0000e+00
# Epoch 111/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3938710.5000 - accuracy: 0.0000e+00 - val_loss: 11368410.0000 - val_accuracy: 0.0000e+00
# Epoch 112/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3902962.0000 - accuracy: 0.0000e+00 - val_loss: 11267928.0000 - val_accuracy: 0.0000e+00
# Epoch 113/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3867821.0000 - accuracy: 0.0000e+00 - val_loss: 11169780.0000 - val_accuracy: 0.0000e+00
# Epoch 114/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3833354.7500 - accuracy: 0.0000e+00 - val_loss: 11073764.0000 - val_accuracy: 0.0000e+00
# Epoch 115/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3799552.5000 - accuracy: 0.0000e+00 - val_loss: 10979999.0000 - val_accuracy: 0.0000e+00
# Epoch 116/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3766401.2500 - accuracy: 0.0000e+00 - val_loss: 10888318.0000 - val_accuracy: 0.0000e+00
# Epoch 117/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3733999.2500 - accuracy: 0.0000e+00 - val_loss: 10798624.0000 - val_accuracy: 0.0000e+00
# Epoch 118/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3702208.5000 - accuracy: 0.0000e+00 - val_loss: 10710869.0000 - val_accuracy: 0.0000e+00
# Epoch 119/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3671028.7500 - accuracy: 0.0000e+00 - val_loss: 10625209.0000 - val_accuracy: 0.0000e+00
# Epoch 120/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3640390.7500 - accuracy: 0.0000e+00 - val_loss: 10542013.0000 - val_accuracy: 0.0000e+00
# Epoch 121/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3610368.2500 - accuracy: 0.0000e+00 - val_loss: 10460552.0000 - val_accuracy: 0.0000e+00
# Epoch 122/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3580911.5000 - accuracy: 0.0000e+00 - val_loss: 10381005.0000 - val_accuracy: 0.0000e+00
# Epoch 123/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3551983.7500 - accuracy: 0.0000e+00 - val_loss: 10303223.0000 - val_accuracy: 0.0000e+00
# Epoch 124/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3523584.0000 - accuracy: 0.0000e+00 - val_loss: 10227077.0000 - val_accuracy: 0.0000e+00
# Epoch 125/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3495706.7500 - accuracy: 0.0000e+00 - val_loss: 10152402.0000 - val_accuracy: 0.0000e+00
# Epoch 126/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3468330.5000 - accuracy: 0.0000e+00 - val_loss: 10079165.0000 - val_accuracy: 0.0000e+00
# Epoch 127/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3441392.5000 - accuracy: 0.0000e+00 - val_loss: 10007391.0000 - val_accuracy: 0.0000e+00
# Epoch 128/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3414802.7500 - accuracy: 0.0000e+00 - val_loss: 9937590.0000 - val_accuracy: 0.0000e+00
# Epoch 129/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3388475.5000 - accuracy: 0.0000e+00 - val_loss: 9868052.0000 - val_accuracy: 0.0000e+00
# Epoch 130/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3362448.5000 - accuracy: 0.0000e+00 - val_loss: 9799711.0000 - val_accuracy: 0.0000e+00
# Epoch 131/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3336694.7500 - accuracy: 0.0000e+00 - val_loss: 9732571.0000 - val_accuracy: 0.0000e+00
# Epoch 132/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3310915.0000 - accuracy: 0.0000e+00 - val_loss: 9665400.0000 - val_accuracy: 0.0000e+00
# Epoch 133/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3285449.5000 - accuracy: 0.0000e+00 - val_loss: 9599779.0000 - val_accuracy: 0.0000e+00
# Epoch 134/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3260629.2500 - accuracy: 0.0000e+00 - val_loss: 9533111.0000 - val_accuracy: 0.0000e+00
# Epoch 135/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3236295.7500 - accuracy: 0.0000e+00 - val_loss: 9465779.0000 - val_accuracy: 0.0000e+00
# Epoch 136/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3212219.2500 - accuracy: 0.0000e+00 - val_loss: 9397417.0000 - val_accuracy: 0.0000e+00
# Epoch 137/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3188501.0000 - accuracy: 0.0000e+00 - val_loss: 9332015.0000 - val_accuracy: 0.0000e+00
# Epoch 138/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3165069.7500 - accuracy: 0.0000e+00 - val_loss: 9259870.0000 - val_accuracy: 0.0000e+00
# Epoch 139/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3141357.5000 - accuracy: 0.0000e+00 - val_loss: 9188613.0000 - val_accuracy: 0.0000e+00
# Epoch 140/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3118069.5000 - accuracy: 0.0000e+00 - val_loss: 9114483.0000 - val_accuracy: 0.0000e+00
# Epoch 141/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3094547.0000 - accuracy: 0.0000e+00 - val_loss: 9048587.0000 - val_accuracy: 0.0000e+00
# Epoch 142/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3071255.0000 - accuracy: 0.0000e+00 - val_loss: 8971258.0000 - val_accuracy: 0.0000e+00
# Epoch 143/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3046440.2500 - accuracy: 0.0000e+00 - val_loss: 8899668.0000 - val_accuracy: 0.0000e+00
# Epoch 144/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3020832.2500 - accuracy: 0.0000e+00 - val_loss: 8812550.0000 - val_accuracy: 0.0000e+00
# Epoch 145/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2994997.0000 - accuracy: 0.0000e+00 - val_loss: 8753218.0000 - val_accuracy: 0.0000e+00
# Epoch 146/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2973187.0000 - accuracy: 0.0000e+00 - val_loss: 8666419.0000 - val_accuracy: 0.0000e+00
# Epoch 147/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2949417.2500 - accuracy: 0.0000e+00 - val_loss: 8634386.0000 - val_accuracy: 0.0000e+00
# Epoch 148/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2933041.2500 - accuracy: 0.0000e+00 - val_loss: 8544957.0000 - val_accuracy: 0.0000e+00
# Epoch 149/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2913676.2500 - accuracy: 0.0000e+00 - val_loss: 8554391.0000 - val_accuracy: 0.0000e+00
# Epoch 150/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2914510.0000 - accuracy: 0.0000e+00 - val_loss: 8430633.0000 - val_accuracy: 0.0000e+00
# Epoch 151/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2921475.5000 - accuracy: 0.0000e+00 - val_loss: 8525965.0000 - val_accuracy: 0.0000e+00
# Epoch 152/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3014018.0000 - accuracy: 0.0000e+00 - val_loss: 8343687.0000 - val_accuracy: 0.0000e+00
# Epoch 153/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3225942.5000 - accuracy: 0.0000e+00 - val_loss: 8696613.0000 - val_accuracy: 0.0000e+00
# Epoch 154/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3958312.5000 - accuracy: 0.0000e+00 - val_loss: 8578579.0000 - val_accuracy: 0.0000e+00
# Epoch 155/200
# 20/20 [==============================] - 0s 1ms/step - loss: 5793752.5000 - accuracy: 0.0000e+00 - val_loss: 9906406.0000 - val_accuracy: 0.0000e+00
# Epoch 156/200
# 20/20 [==============================] - 0s 1ms/step - loss: 11579779.0000 - accuracy: 0.0000e+00 - val_loss: 12375122.0000 - val_accuracy: 0.0000e+00
# Epoch 157/200
# 20/20 [==============================] - 0s 1ms/step - loss: 25274788.0000 - accuracy: 0.0000e+00 - val_loss: 19149928.0000 - val_accuracy: 0.0000e+00
# Epoch 158/200
# 20/20 [==============================] - 0s 2ms/step - loss: 64717868.0000 - accuracy: 0.0000e+00 - val_loss: 79633896.0000 - val_accuracy: 0.0000e+00
# Epoch 159/200
# 20/20 [==============================] - 0s 1ms/step - loss: 98592096.0000 - accuracy: 0.0000e+00 - val_loss: 127988568.0000 - val_accuracy: 0.0000e+00
# Epoch 160/200
# 20/20 [==============================] - 0s 1ms/step - loss: 121433608.0000 - accuracy: 0.0000e+00 - val_loss: 372498432.0000 - val_accuracy: 0.0000e+00
# Epoch 161/200
# 20/20 [==============================] - 0s 1ms/step - loss: 18695542.0000 - accuracy: 0.0000e+00 - val_loss: 65921496.0000 - val_accuracy: 0.0000e+00
# Epoch 162/200
# 20/20 [==============================] - 0s 1ms/step - loss: 6097828.5000 - accuracy: 0.0000e+00 - val_loss: 17320496.0000 - val_accuracy: 0.0000e+00
# Epoch 163/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4659651.5000 - accuracy: 0.0000e+00 - val_loss: 13890389.0000 - val_accuracy: 0.0000e+00
# Epoch 164/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4562484.0000 - accuracy: 0.0000e+00 - val_loss: 13571070.0000 - val_accuracy: 0.0000e+00
# Epoch 165/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4485758.5000 - accuracy: 0.0000e+00 - val_loss: 13028748.0000 - val_accuracy: 0.0000e+00
# Epoch 166/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4380944.5000 - accuracy: 0.0000e+00 - val_loss: 12775742.0000 - val_accuracy: 0.0000e+00
# Epoch 167/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4277990.5000 - accuracy: 0.0000e+00 - val_loss: 12339757.0000 - val_accuracy: 0.0000e+00
# Epoch 168/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4172247.5000 - accuracy: 0.0000e+00 - val_loss: 11946719.0000 - val_accuracy: 0.0000e+00
# Epoch 169/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4079260.2500 - accuracy: 0.0000e+00 - val_loss: 11628426.0000 - val_accuracy: 0.0000e+00
# Epoch 170/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4003377.5000 - accuracy: 0.0000e+00 - val_loss: 11365562.0000 - val_accuracy: 0.0000e+00
# Epoch 171/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3937732.5000 - accuracy: 0.0000e+00 - val_loss: 11162766.0000 - val_accuracy: 0.0000e+00
# Epoch 172/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3877055.2500 - accuracy: 0.0000e+00 - val_loss: 11006915.0000 - val_accuracy: 0.0000e+00
# Epoch 173/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3816835.0000 - accuracy: 0.0000e+00 - val_loss: 10891805.0000 - val_accuracy: 0.0000e+00
# Epoch 174/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3763168.2500 - accuracy: 0.0000e+00 - val_loss: 10791179.0000 - val_accuracy: 0.0000e+00
# Epoch 175/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3709020.0000 - accuracy: 0.0000e+00 - val_loss: 10700143.0000 - val_accuracy: 0.0000e+00
# Epoch 176/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3651792.0000 - accuracy: 0.0000e+00 - val_loss: 10605760.0000 - val_accuracy: 0.0000e+00
# Epoch 177/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3589794.7500 - accuracy: 0.0000e+00 - val_loss: 10494074.0000 - val_accuracy: 0.0000e+00
# Epoch 178/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3519806.0000 - accuracy: 0.0000e+00 - val_loss: 10332368.0000 - val_accuracy: 0.0000e+00
# Epoch 179/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3442186.5000 - accuracy: 0.0000e+00 - val_loss: 10061443.0000 - val_accuracy: 0.0000e+00
# Epoch 180/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3365216.5000 - accuracy: 0.0000e+00 - val_loss: 9773619.0000 - val_accuracy: 0.0000e+00
# Epoch 181/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3287012.7500 - accuracy: 0.0000e+00 - val_loss: 9478415.0000 - val_accuracy: 0.0000e+00
# Epoch 182/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3208621.0000 - accuracy: 0.0000e+00 - val_loss: 9198232.0000 - val_accuracy: 0.0000e+00
# Epoch 183/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3135146.5000 - accuracy: 0.0000e+00 - val_loss: 8947846.0000 - val_accuracy: 0.0000e+00
# Epoch 184/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3074215.2500 - accuracy: 0.0000e+00 - val_loss: 8764551.0000 - val_accuracy: 0.0000e+00
# Epoch 185/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3025420.2500 - accuracy: 0.0000e+00 - val_loss: 8630497.0000 - val_accuracy: 0.0000e+00
# Epoch 186/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2984182.7500 - accuracy: 0.0000e+00 - val_loss: 8530327.0000 - val_accuracy: 0.0000e+00
# Epoch 187/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2947726.2500 - accuracy: 0.0000e+00 - val_loss: 8450320.0000 - val_accuracy: 0.0000e+00
# Epoch 188/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2914551.2500 - accuracy: 0.0000e+00 - val_loss: 8391911.0000 - val_accuracy: 0.0000e+00
# Epoch 189/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2884870.0000 - accuracy: 0.0000e+00 - val_loss: 8340775.0000 - val_accuracy: 0.0000e+00
# Epoch 190/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2858972.0000 - accuracy: 0.0000e+00 - val_loss: 8289780.5000 - val_accuracy: 0.0000e+00
# Epoch 191/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2835379.7500 - accuracy: 0.0000e+00 - val_loss: 8242211.0000 - val_accuracy: 0.0000e+00
# Epoch 192/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2813876.0000 - accuracy: 0.0000e+00 - val_loss: 8193161.5000 - val_accuracy: 0.0000e+00
# Epoch 193/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2793310.0000 - accuracy: 0.0000e+00 - val_loss: 8149259.5000 - val_accuracy: 0.0000e+00
# Epoch 194/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2773683.7500 - accuracy: 0.0000e+00 - val_loss: 8100316.5000 - val_accuracy: 0.0000e+00
# Epoch 195/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2754616.5000 - accuracy: 0.0000e+00 - val_loss: 8059724.5000 - val_accuracy: 0.0000e+00
# Epoch 196/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2736534.0000 - accuracy: 0.0000e+00 - val_loss: 8012756.0000 - val_accuracy: 0.0000e+00
# Epoch 197/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2718532.7500 - accuracy: 0.0000e+00 - val_loss: 7974419.0000 - val_accuracy: 0.0000e+00
# Epoch 198/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2701429.7500 - accuracy: 0.0000e+00 - val_loss: 7929524.5000 - val_accuracy: 0.0000e+00
# Epoch 199/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2684424.7500 - accuracy: 0.0000e+00 - val_loss: 7895637.5000 - val_accuracy: 0.0000e+00
# Epoch 200/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2668321.0000 - accuracy: 0.0000e+00 - val_loss: 7848638.5000 - val_accuracy: 0.0000e+00

# %%
y_predicted = network.predict(X_test, verbose=1)
result = test_data.iloc[window_size:]
result['Predicted'] = y_predicted
result[['Close','Predicted']]
# Out:
# 11/11 [==============================] - 0s 522us/step
# <ipython-input-22-f75e88b767c6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['Predicted'] = y_predicted
#                    Close     Predicted
# Date
# 2022-05-18  28720.271484  30631.205078
# 2022-05-19  30314.333984  30214.458984
# 2022-05-20  29200.740234  29949.500000
# 2022-05-21  29432.226563  29773.441406
# 2022-05-22  30323.722656  29748.394531
# ...                  ...           ...
# 2023-04-28  29340.261719  28526.552734
# 2023-04-29  29248.488281  28627.222656
# 2023-04-30  29268.806641  28960.777344
# 2023-05-01  28091.568359  28987.548828
# 2023-05-02  28676.791016  28957.789062
#
# [350 rows x 2 columns]

# %%
test_set_range = result.index
plt.figure(figsize=(20,10))
plt.plot(test_set_range, result['Predicted'], color='blue', marker='o', linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range, result['Close'], color='red', label='Actual Price')
plt.title('BTC Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

MSE = mean_squared_error(result['Close'], result['Predicted'])
RMSE = mean_squared_error(result['Close'], result['Predicted'], squared=False)
MAE = mean_absolute_error(result['Close'], result['Predicted'])
R2 = r2_score(result['Close'], result['Predicted'])

# %%
import pandas as pd

# Değerleri bir sözlük yapısında sakla
results = {'MSE': [MSE], 'RMSE': [RMSE], 'MAE': [MAE], 'R2': [R2]}

# DataFrame oluştur ve index değerlerini varsayılan değerlerle ata
MLP_ERROR= pd.DataFrame.from_dict(results, orient='index').T

# DataFrame'i ERROR ismiyle kaydet
MLP_ERROR = MLP_ERROR.to_string(index=False)

# ERROR'u yazdır

print(MLP_ERROR)
# Out:
#          MSE        RMSE        MAE       R2
# 1.940996e+06 1393.196181 956.587394 0.887197
