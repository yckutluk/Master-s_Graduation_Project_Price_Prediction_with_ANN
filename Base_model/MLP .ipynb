# %% [markdown]
# <h1 style="font-size:36px;">Multilayer Perceptron</h1>

# %% [markdown]
# MLP is a deep learning method that aims to learn complex relationships between data by using artificial neural network structure. The MLP model for Bitcoin price prediction attempts to predict future prices using historical price data. The model has a network structure consisting of many hidden layers, and nodes in each layer generate an output using inputs from all nodes in the previous layer. The accuracy of the model depends on many factors such as the learning rate, parameter settings, and the features used.
#
# MLP, yapay sinir ağı yapısını kullanarak, veriler arasındaki kompleks ilişkileri öğrenmeyi amaçlayan bir derin öğrenme yöntemidir. Bitcoin fiyat tahmini yapmak için kullanılan MLP modeli, tarihsel fiyat verilerini kullanarak gelecekteki fiyatları tahmin etmeye çalışır. Model, birçok gizli katmandan oluşan bir ağ yapısına sahiptir ve her katmandaki düğümler, önceki katmandaki tüm düğümlerden gelen girdileri kullanarak bir çıkış üretir. Modelin doğruluğu, öğrenme oranı, parametre ayarları ve kullanılan özellikler gibi birçok faktöre bağlıdır.

# %% [markdown]
# <h1 style="font-size:15px;">Summary of the Model</h1>

# %% [markdown]
# Optimizer: Adam
# Learning rate: 0.001
# Loss: Mse
# Metrics: Accuracy

# %%
network.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 100)               4100
#
#  dense_5 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 4,201
# Trainable params: 4,201
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# This model includes two dense layers. The first layer has 100 output neurons. The second layer has only one output neuron. The total number of parameters is 4201 and the number of trainable parameters is also 4201. This model can be used for regression problems and the output of the model is a number.
#
# Bu model, iki adet yoğun katman içerir. İlk katman,  100 adet çıktı nöronuna sahiptir. İkinci katman,  sadece bir adet çıktı nöronuna sahiptir. Toplam parametre sayısı 4201'dir ve eğitilebilir parametre sayısı da 4201'dir. Bu model, regresyon problemleri için kullanılabilir ve modelin çıkışı bir sayıdır.

# %% [markdown]
# <h1 style="font-size:15px;">Outputs Model</h1>

# %%
print(MLP_ERROR)
# Out:
#          MSE        RMSE         MAE       R2
# 2.715959e+06 1648.016588 1460.566791 0.842159

# %% [markdown]
# <h3 style="font-size:24px;">Data preprocessing and Preparation</h3>

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras import models,layers,optimizers,callbacks
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('btcusd.csv',usecols=['Open','High','Low','Close','Date'])
df.Date = pd.to_datetime(df.Date, format="%Y-%m-%d")
df.set_index('Date',inplace=True)
print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3150 entries, 2014-09-17 to 2023-05-02
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3150 non-null   float64
#  1   High    3150 non-null   float64
#  2   Low     3150 non-null   float64
#  3   Close   3150 non-null   float64
# dtypes: float64(4)
# memory usage: 123.0 KB
# None
#                     Open          High           Low         Close
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-04-28  29481.013672  29572.791016  28929.609375  29340.261719
# 2023-04-29  29336.566406  29452.455078  29088.042969  29248.488281
# 2023-04-30  29245.515625  29952.029297  29114.021484  29268.806641
# 2023-05-01  29227.103516  29329.935547  27680.792969  28091.568359
# 2023-05-02  28011.582031  28852.992188  27928.583984  28676.791016
#
# [3150 rows x 4 columns]

# %%
plt.figure(figsize=(20,9))
df = df['2018':]
plt.plot(df.index, df["Close"])
plt.xticks(df[::90].index, df[::90].index.date,rotation = -46)
plt.title("BTC stock price over time")
plt.xlabel("time")
plt.ylabel("price")
plt.show()

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
train_data, test_data = train_test_split(df,random_state=42,test_size=0.2,shuffle=False) 
window_size = 40
X_train, y_train = split_sequence(train_data["Close"].values, window_size)
X_test, y_test = split_sequence(test_data["Close"].values, window_size)

# %% [markdown]
# # MLP Model

# %%
network = models.Sequential([
  layers.Dense(100, activation='relu', input_dim=window_size),  
  layers.Dense(1)
])
# network.compile(optimizer=optimizers.Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy']) #loss='mse
network.compile(optimizer=optimizers.Adam(learning_rate=0.001),loss='mse',metrics=['accuracy']) 
network.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 100)               4100
#
#  dense_5 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 4,201
# Trainable params: 4,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
cb = callbacks.TensorBoard()
trained_network=network.fit(X_train, y_train, epochs=200, batch_size=64,verbose=1,callbacks=[cb],validation_split=0.16,shuffle=False)
# Out:
# Epoch 1/200
# 20/20 [==============================] - 0s 5ms/step - loss: 23780638.0000 - accuracy: 0.0000e+00 - val_loss: 31933650.0000 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 20/20 [==============================] - 0s 1ms/step - loss: 8640669.0000 - accuracy: 0.0000e+00 - val_loss: 35886836.0000 - val_accuracy: 0.0000e+00
# Epoch 3/200
# 20/20 [==============================] - 0s 2ms/step - loss: 9641727.0000 - accuracy: 0.0000e+00 - val_loss: 19961026.0000 - val_accuracy: 0.0000e+00
# Epoch 4/200
# 20/20 [==============================] - 0s 2ms/step - loss: 8357574.0000 - accuracy: 0.0000e+00 - val_loss: 21309734.0000 - val_accuracy: 0.0000e+00
# Epoch 5/200
# 20/20 [==============================] - 0s 2ms/step - loss: 5910963.0000 - accuracy: 0.0000e+00 - val_loss: 18251990.0000 - val_accuracy: 0.0000e+00
# Epoch 6/200
# 20/20 [==============================] - 0s 2ms/step - loss: 5590550.0000 - accuracy: 0.0000e+00 - val_loss: 19805762.0000 - val_accuracy: 0.0000e+00
# Epoch 7/200
# 20/20 [==============================] - 0s 2ms/step - loss: 5553897.5000 - accuracy: 0.0000e+00 - val_loss: 15214194.0000 - val_accuracy: 0.0000e+00
# Epoch 8/200
# 20/20 [==============================] - 0s 1ms/step - loss: 4923828.0000 - accuracy: 0.0000e+00 - val_loss: 13242493.0000 - val_accuracy: 0.0000e+00
# Epoch 9/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4364392.5000 - accuracy: 0.0000e+00 - val_loss: 13478118.0000 - val_accuracy: 0.0000e+00
# Epoch 10/200
# 20/20 [==============================] - 0s 2ms/step - loss: 4101818.2500 - accuracy: 0.0000e+00 - val_loss: 13587050.0000 - val_accuracy: 0.0000e+00
# Epoch 11/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3979213.5000 - accuracy: 0.0000e+00 - val_loss: 14804885.0000 - val_accuracy: 0.0000e+00
# Epoch 12/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3917040.2500 - accuracy: 0.0000e+00 - val_loss: 14182627.0000 - val_accuracy: 0.0000e+00
# Epoch 13/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3777687.0000 - accuracy: 0.0000e+00 - val_loss: 13668712.0000 - val_accuracy: 0.0000e+00
# Epoch 14/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3661038.5000 - accuracy: 0.0000e+00 - val_loss: 13939002.0000 - val_accuracy: 0.0000e+00
# Epoch 15/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3556499.5000 - accuracy: 0.0000e+00 - val_loss: 12721008.0000 - val_accuracy: 0.0000e+00
# Epoch 16/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3332408.7500 - accuracy: 0.0000e+00 - val_loss: 13903707.0000 - val_accuracy: 0.0000e+00
# Epoch 17/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3310743.5000 - accuracy: 0.0000e+00 - val_loss: 13652779.0000 - val_accuracy: 0.0000e+00
# Epoch 18/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3237315.0000 - accuracy: 0.0000e+00 - val_loss: 14417596.0000 - val_accuracy: 0.0000e+00
# Epoch 19/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3228483.7500 - accuracy: 0.0000e+00 - val_loss: 14819020.0000 - val_accuracy: 0.0000e+00
# Epoch 20/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3224513.2500 - accuracy: 0.0000e+00 - val_loss: 16168731.0000 - val_accuracy: 0.0000e+00
# Epoch 21/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3309821.7500 - accuracy: 0.0000e+00 - val_loss: 16267050.0000 - val_accuracy: 0.0000e+00
# Epoch 22/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3272610.7500 - accuracy: 0.0000e+00 - val_loss: 17994460.0000 - val_accuracy: 0.0000e+00
# Epoch 23/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3411658.7500 - accuracy: 0.0000e+00 - val_loss: 18889096.0000 - val_accuracy: 0.0000e+00
# Epoch 24/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3480066.7500 - accuracy: 0.0000e+00 - val_loss: 17044742.0000 - val_accuracy: 0.0000e+00
# Epoch 25/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3220105.5000 - accuracy: 0.0000e+00 - val_loss: 17138982.0000 - val_accuracy: 0.0000e+00
# Epoch 26/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3251413.2500 - accuracy: 0.0000e+00 - val_loss: 18978808.0000 - val_accuracy: 0.0000e+00
# Epoch 27/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3330260.0000 - accuracy: 0.0000e+00 - val_loss: 16208836.0000 - val_accuracy: 0.0000e+00
# Epoch 28/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3116003.0000 - accuracy: 0.0000e+00 - val_loss: 18236480.0000 - val_accuracy: 0.0000e+00
# Epoch 29/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3181280.0000 - accuracy: 0.0000e+00 - val_loss: 15632053.0000 - val_accuracy: 0.0000e+00
# Epoch 30/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2972389.7500 - accuracy: 0.0000e+00 - val_loss: 18051710.0000 - val_accuracy: 0.0000e+00
# Epoch 31/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3091358.7500 - accuracy: 0.0000e+00 - val_loss: 16475487.0000 - val_accuracy: 0.0000e+00
# Epoch 32/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2984196.0000 - accuracy: 0.0000e+00 - val_loss: 18296336.0000 - val_accuracy: 0.0000e+00
# Epoch 33/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3057197.7500 - accuracy: 0.0000e+00 - val_loss: 16323881.0000 - val_accuracy: 0.0000e+00
# Epoch 34/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2916784.0000 - accuracy: 0.0000e+00 - val_loss: 19164550.0000 - val_accuracy: 0.0000e+00
# Epoch 35/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3065912.5000 - accuracy: 0.0000e+00 - val_loss: 16849942.0000 - val_accuracy: 0.0000e+00
# Epoch 36/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2925644.0000 - accuracy: 0.0000e+00 - val_loss: 19416994.0000 - val_accuracy: 0.0000e+00
# Epoch 37/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3053799.2500 - accuracy: 0.0000e+00 - val_loss: 16695280.0000 - val_accuracy: 0.0000e+00
# Epoch 38/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2881362.0000 - accuracy: 0.0000e+00 - val_loss: 19467942.0000 - val_accuracy: 0.0000e+00
# Epoch 39/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3039353.0000 - accuracy: 0.0000e+00 - val_loss: 16456873.0000 - val_accuracy: 0.0000e+00
# Epoch 40/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2803601.2500 - accuracy: 0.0000e+00 - val_loss: 19690426.0000 - val_accuracy: 0.0000e+00
# Epoch 41/200
# 20/20 [==============================] - 0s 1ms/step - loss: 3031421.5000 - accuracy: 0.0000e+00 - val_loss: 17738240.0000 - val_accuracy: 0.0000e+00
# Epoch 42/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2919551.5000 - accuracy: 0.0000e+00 - val_loss: 20059644.0000 - val_accuracy: 0.0000e+00
# Epoch 43/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3070894.2500 - accuracy: 0.0000e+00 - val_loss: 17502342.0000 - val_accuracy: 0.0000e+00
# Epoch 44/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2865814.5000 - accuracy: 0.0000e+00 - val_loss: 19687466.0000 - val_accuracy: 0.0000e+00
# Epoch 45/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3025856.2500 - accuracy: 0.0000e+00 - val_loss: 17990616.0000 - val_accuracy: 0.0000e+00
# Epoch 46/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2913733.2500 - accuracy: 0.0000e+00 - val_loss: 19347732.0000 - val_accuracy: 0.0000e+00
# Epoch 47/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2995592.0000 - accuracy: 0.0000e+00 - val_loss: 17017588.0000 - val_accuracy: 0.0000e+00
# Epoch 48/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2837024.2500 - accuracy: 0.0000e+00 - val_loss: 20625732.0000 - val_accuracy: 0.0000e+00
# Epoch 49/200
# 20/20 [==============================] - 0s 2ms/step - loss: 3098438.7500 - accuracy: 0.0000e+00 - val_loss: 16189446.0000 - val_accuracy: 0.0000e+00
# Epoch 50/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2683223.7500 - accuracy: 0.0000e+00 - val_loss: 18480990.0000 - val_accuracy: 0.0000e+00
# Epoch 51/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2892784.0000 - accuracy: 0.0000e+00 - val_loss: 18038738.0000 - val_accuracy: 0.0000e+00
# Epoch 52/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2868670.2500 - accuracy: 0.0000e+00 - val_loss: 17142558.0000 - val_accuracy: 0.0000e+00
# Epoch 53/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2785224.7500 - accuracy: 0.0000e+00 - val_loss: 18373968.0000 - val_accuracy: 0.0000e+00
# Epoch 54/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2876775.0000 - accuracy: 0.0000e+00 - val_loss: 16187798.0000 - val_accuracy: 0.0000e+00
# Epoch 55/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2673867.7500 - accuracy: 0.0000e+00 - val_loss: 18790378.0000 - val_accuracy: 0.0000e+00
# Epoch 56/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2885885.0000 - accuracy: 0.0000e+00 - val_loss: 15929495.0000 - val_accuracy: 0.0000e+00
# Epoch 57/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2600358.2500 - accuracy: 0.0000e+00 - val_loss: 18042078.0000 - val_accuracy: 0.0000e+00
# Epoch 58/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2802555.7500 - accuracy: 0.0000e+00 - val_loss: 17257358.0000 - val_accuracy: 0.0000e+00
# Epoch 59/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2724270.2500 - accuracy: 0.0000e+00 - val_loss: 16386286.0000 - val_accuracy: 0.0000e+00
# Epoch 60/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2646814.0000 - accuracy: 0.0000e+00 - val_loss: 17981806.0000 - val_accuracy: 0.0000e+00
# Epoch 61/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2765146.5000 - accuracy: 0.0000e+00 - val_loss: 15252497.0000 - val_accuracy: 0.0000e+00
# Epoch 62/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2506750.5000 - accuracy: 0.0000e+00 - val_loss: 18311434.0000 - val_accuracy: 0.0000e+00
# Epoch 63/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2757534.7500 - accuracy: 0.0000e+00 - val_loss: 16017172.0000 - val_accuracy: 0.0000e+00
# Epoch 64/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2606827.0000 - accuracy: 0.0000e+00 - val_loss: 17399034.0000 - val_accuracy: 0.0000e+00
# Epoch 65/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2708040.0000 - accuracy: 0.0000e+00 - val_loss: 13896783.0000 - val_accuracy: 0.0000e+00
# Epoch 66/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2349564.0000 - accuracy: 0.0000e+00 - val_loss: 16070309.0000 - val_accuracy: 0.0000e+00
# Epoch 67/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2451434.0000 - accuracy: 0.0000e+00 - val_loss: 14603017.0000 - val_accuracy: 0.0000e+00
# Epoch 68/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2391083.7500 - accuracy: 0.0000e+00 - val_loss: 17239368.0000 - val_accuracy: 0.0000e+00
# Epoch 69/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2652742.5000 - accuracy: 0.0000e+00 - val_loss: 15356334.0000 - val_accuracy: 0.0000e+00
# Epoch 70/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2505097.2500 - accuracy: 0.0000e+00 - val_loss: 18862412.0000 - val_accuracy: 0.0000e+00
# Epoch 71/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2808053.0000 - accuracy: 0.0000e+00 - val_loss: 14870456.0000 - val_accuracy: 0.0000e+00
# Epoch 72/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2404458.5000 - accuracy: 0.0000e+00 - val_loss: 17522158.0000 - val_accuracy: 0.0000e+00
# Epoch 73/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2603114.7500 - accuracy: 0.0000e+00 - val_loss: 17074426.0000 - val_accuracy: 0.0000e+00
# Epoch 74/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2628413.7500 - accuracy: 0.0000e+00 - val_loss: 16956836.0000 - val_accuracy: 0.0000e+00
# Epoch 75/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2628453.5000 - accuracy: 0.0000e+00 - val_loss: 16415148.0000 - val_accuracy: 0.0000e+00
# Epoch 76/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2581880.2500 - accuracy: 0.0000e+00 - val_loss: 17410430.0000 - val_accuracy: 0.0000e+00
# Epoch 77/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2670993.7500 - accuracy: 0.0000e+00 - val_loss: 15433498.0000 - val_accuracy: 0.0000e+00
# Epoch 78/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2506640.0000 - accuracy: 0.0000e+00 - val_loss: 18828456.0000 - val_accuracy: 0.0000e+00
# Epoch 79/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2802734.2500 - accuracy: 0.0000e+00 - val_loss: 14062607.0000 - val_accuracy: 0.0000e+00
# Epoch 80/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2279755.0000 - accuracy: 0.0000e+00 - val_loss: 14599648.0000 - val_accuracy: 0.0000e+00
# Epoch 81/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2332548.5000 - accuracy: 0.0000e+00 - val_loss: 15468549.0000 - val_accuracy: 0.0000e+00
# Epoch 82/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2383005.7500 - accuracy: 0.0000e+00 - val_loss: 14992635.0000 - val_accuracy: 0.0000e+00
# Epoch 83/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2376875.7500 - accuracy: 0.0000e+00 - val_loss: 16010471.0000 - val_accuracy: 0.0000e+00
# Epoch 84/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2481481.7500 - accuracy: 0.0000e+00 - val_loss: 16703311.0000 - val_accuracy: 0.0000e+00
# Epoch 85/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2576313.7500 - accuracy: 0.0000e+00 - val_loss: 17541254.0000 - val_accuracy: 0.0000e+00
# Epoch 86/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2708679.0000 - accuracy: 0.0000e+00 - val_loss: 16621857.0000 - val_accuracy: 0.0000e+00
# Epoch 87/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2662784.7500 - accuracy: 0.0000e+00 - val_loss: 17534314.0000 - val_accuracy: 0.0000e+00
# Epoch 88/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2738040.5000 - accuracy: 0.0000e+00 - val_loss: 14052445.0000 - val_accuracy: 0.0000e+00
# Epoch 89/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2335366.0000 - accuracy: 0.0000e+00 - val_loss: 15430503.0000 - val_accuracy: 0.0000e+00
# Epoch 90/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2464365.2500 - accuracy: 0.0000e+00 - val_loss: 15807552.0000 - val_accuracy: 0.0000e+00
# Epoch 91/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2508384.5000 - accuracy: 0.0000e+00 - val_loss: 16127057.0000 - val_accuracy: 0.0000e+00
# Epoch 92/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2584493.0000 - accuracy: 0.0000e+00 - val_loss: 14672247.0000 - val_accuracy: 0.0000e+00
# Epoch 93/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2450540.2500 - accuracy: 0.0000e+00 - val_loss: 15675560.0000 - val_accuracy: 0.0000e+00
# Epoch 94/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2546646.7500 - accuracy: 0.0000e+00 - val_loss: 13552006.0000 - val_accuracy: 0.0000e+00
# Epoch 95/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2316781.5000 - accuracy: 0.0000e+00 - val_loss: 16860404.0000 - val_accuracy: 0.0000e+00
# Epoch 96/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2615399.0000 - accuracy: 0.0000e+00 - val_loss: 12894245.0000 - val_accuracy: 0.0000e+00
# Epoch 97/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2212853.2500 - accuracy: 0.0000e+00 - val_loss: 14912630.0000 - val_accuracy: 0.0000e+00
# Epoch 98/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2418603.7500 - accuracy: 0.0000e+00 - val_loss: 11924065.0000 - val_accuracy: 0.0000e+00
# Epoch 99/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2057576.0000 - accuracy: 0.0000e+00 - val_loss: 13464445.0000 - val_accuracy: 0.0000e+00
# Epoch 100/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2203742.2500 - accuracy: 0.0000e+00 - val_loss: 14383757.0000 - val_accuracy: 0.0000e+00
# Epoch 101/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2287559.5000 - accuracy: 0.0000e+00 - val_loss: 15071079.0000 - val_accuracy: 0.0000e+00
# Epoch 102/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2384702.7500 - accuracy: 0.0000e+00 - val_loss: 13917637.0000 - val_accuracy: 0.0000e+00
# Epoch 103/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2288317.0000 - accuracy: 0.0000e+00 - val_loss: 15858937.0000 - val_accuracy: 0.0000e+00
# Epoch 104/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2488005.2500 - accuracy: 0.0000e+00 - val_loss: 12857549.0000 - val_accuracy: 0.0000e+00
# Epoch 105/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2103195.5000 - accuracy: 0.0000e+00 - val_loss: 14197387.0000 - val_accuracy: 0.0000e+00
# Epoch 106/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2253336.2500 - accuracy: 0.0000e+00 - val_loss: 15057265.0000 - val_accuracy: 0.0000e+00
# Epoch 107/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2360670.2500 - accuracy: 0.0000e+00 - val_loss: 14647108.0000 - val_accuracy: 0.0000e+00
# Epoch 108/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2334062.7500 - accuracy: 0.0000e+00 - val_loss: 16175190.0000 - val_accuracy: 0.0000e+00
# Epoch 109/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2488450.5000 - accuracy: 0.0000e+00 - val_loss: 13271612.0000 - val_accuracy: 0.0000e+00
# Epoch 110/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2168998.0000 - accuracy: 0.0000e+00 - val_loss: 16683061.0000 - val_accuracy: 0.0000e+00
# Epoch 111/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2550237.0000 - accuracy: 0.0000e+00 - val_loss: 12634104.0000 - val_accuracy: 0.0000e+00
# Epoch 112/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2052138.6250 - accuracy: 0.0000e+00 - val_loss: 12572542.0000 - val_accuracy: 0.0000e+00
# Epoch 113/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2053461.5000 - accuracy: 0.0000e+00 - val_loss: 14333145.0000 - val_accuracy: 0.0000e+00
# Epoch 114/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2309266.2500 - accuracy: 0.0000e+00 - val_loss: 16345832.0000 - val_accuracy: 0.0000e+00
# Epoch 115/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2513162.2500 - accuracy: 0.0000e+00 - val_loss: 15145102.0000 - val_accuracy: 0.0000e+00
# Epoch 116/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2427445.5000 - accuracy: 0.0000e+00 - val_loss: 18683400.0000 - val_accuracy: 0.0000e+00
# Epoch 117/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2777938.5000 - accuracy: 0.0000e+00 - val_loss: 13027945.0000 - val_accuracy: 0.0000e+00
# Epoch 118/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2117610.0000 - accuracy: 0.0000e+00 - val_loss: 12194370.0000 - val_accuracy: 0.0000e+00
# Epoch 119/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2034051.8750 - accuracy: 0.0000e+00 - val_loss: 12749275.0000 - val_accuracy: 0.0000e+00
# Epoch 120/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2182730.2500 - accuracy: 0.0000e+00 - val_loss: 16319193.0000 - val_accuracy: 0.0000e+00
# Epoch 121/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2523410.0000 - accuracy: 0.0000e+00 - val_loss: 12951846.0000 - val_accuracy: 0.0000e+00
# Epoch 122/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2123366.5000 - accuracy: 0.0000e+00 - val_loss: 12769912.0000 - val_accuracy: 0.0000e+00
# Epoch 123/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2199729.5000 - accuracy: 0.0000e+00 - val_loss: 16622568.0000 - val_accuracy: 0.0000e+00
# Epoch 124/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2441157.2500 - accuracy: 0.0000e+00 - val_loss: 12857337.0000 - val_accuracy: 0.0000e+00
# Epoch 125/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2130419.2500 - accuracy: 0.0000e+00 - val_loss: 13250674.0000 - val_accuracy: 0.0000e+00
# Epoch 126/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2200011.5000 - accuracy: 0.0000e+00 - val_loss: 14731423.0000 - val_accuracy: 0.0000e+00
# Epoch 127/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2407520.5000 - accuracy: 0.0000e+00 - val_loss: 15263057.0000 - val_accuracy: 0.0000e+00
# Epoch 128/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2498794.5000 - accuracy: 0.0000e+00 - val_loss: 14873751.0000 - val_accuracy: 0.0000e+00
# Epoch 129/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2474698.2500 - accuracy: 0.0000e+00 - val_loss: 14460262.0000 - val_accuracy: 0.0000e+00
# Epoch 130/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2447521.5000 - accuracy: 0.0000e+00 - val_loss: 13002936.0000 - val_accuracy: 0.0000e+00
# Epoch 131/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2289659.0000 - accuracy: 0.0000e+00 - val_loss: 12718885.0000 - val_accuracy: 0.0000e+00
# Epoch 132/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2263018.5000 - accuracy: 0.0000e+00 - val_loss: 11374435.0000 - val_accuracy: 0.0000e+00
# Epoch 133/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2094953.6250 - accuracy: 0.0000e+00 - val_loss: 11603717.0000 - val_accuracy: 0.0000e+00
# Epoch 134/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2090145.2500 - accuracy: 0.0000e+00 - val_loss: 9552193.0000 - val_accuracy: 0.0000e+00
# Epoch 135/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1836963.5000 - accuracy: 0.0000e+00 - val_loss: 11309011.0000 - val_accuracy: 0.0000e+00
# Epoch 136/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1995067.8750 - accuracy: 0.0000e+00 - val_loss: 8576344.0000 - val_accuracy: 0.0000e+00
# Epoch 137/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1635786.7500 - accuracy: 0.0000e+00 - val_loss: 10632319.0000 - val_accuracy: 0.0000e+00
# Epoch 138/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1770216.7500 - accuracy: 0.0000e+00 - val_loss: 9625050.0000 - val_accuracy: 0.0000e+00
# Epoch 139/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1683473.8750 - accuracy: 0.0000e+00 - val_loss: 10978907.0000 - val_accuracy: 0.0000e+00
# Epoch 140/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1794852.7500 - accuracy: 0.0000e+00 - val_loss: 11433816.0000 - val_accuracy: 0.0000e+00
# Epoch 141/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1826579.6250 - accuracy: 0.0000e+00 - val_loss: 12117394.0000 - val_accuracy: 0.0000e+00
# Epoch 142/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1865885.3750 - accuracy: 0.0000e+00 - val_loss: 11482591.0000 - val_accuracy: 0.0000e+00
# Epoch 143/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1838109.5000 - accuracy: 0.0000e+00 - val_loss: 12876134.0000 - val_accuracy: 0.0000e+00
# Epoch 144/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1956813.0000 - accuracy: 0.0000e+00 - val_loss: 13042287.0000 - val_accuracy: 0.0000e+00
# Epoch 145/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1976491.8750 - accuracy: 0.0000e+00 - val_loss: 13869201.0000 - val_accuracy: 0.0000e+00
# Epoch 146/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2056840.8750 - accuracy: 0.0000e+00 - val_loss: 13914459.0000 - val_accuracy: 0.0000e+00
# Epoch 147/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2066724.7500 - accuracy: 0.0000e+00 - val_loss: 14166043.0000 - val_accuracy: 0.0000e+00
# Epoch 148/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2114598.7500 - accuracy: 0.0000e+00 - val_loss: 14549732.0000 - val_accuracy: 0.0000e+00
# Epoch 149/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2170229.7500 - accuracy: 0.0000e+00 - val_loss: 14512283.0000 - val_accuracy: 0.0000e+00
# Epoch 150/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2221098.2500 - accuracy: 0.0000e+00 - val_loss: 16589270.0000 - val_accuracy: 0.0000e+00
# Epoch 151/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2424858.5000 - accuracy: 0.0000e+00 - val_loss: 14784951.0000 - val_accuracy: 0.0000e+00
# Epoch 152/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2333828.0000 - accuracy: 0.0000e+00 - val_loss: 16650222.0000 - val_accuracy: 0.0000e+00
# Epoch 153/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2547333.5000 - accuracy: 0.0000e+00 - val_loss: 12514484.0000 - val_accuracy: 0.0000e+00
# Epoch 154/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2072394.5000 - accuracy: 0.0000e+00 - val_loss: 14402383.0000 - val_accuracy: 0.0000e+00
# Epoch 155/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2236462.2500 - accuracy: 0.0000e+00 - val_loss: 11482818.0000 - val_accuracy: 0.0000e+00
# Epoch 156/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1994628.5000 - accuracy: 0.0000e+00 - val_loss: 14417503.0000 - val_accuracy: 0.0000e+00
# Epoch 157/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2195691.7500 - accuracy: 0.0000e+00 - val_loss: 10630662.0000 - val_accuracy: 0.0000e+00
# Epoch 158/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1843584.2500 - accuracy: 0.0000e+00 - val_loss: 10466560.0000 - val_accuracy: 0.0000e+00
# Epoch 159/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1849604.3750 - accuracy: 0.0000e+00 - val_loss: 10403170.0000 - val_accuracy: 0.0000e+00
# Epoch 160/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1832744.0000 - accuracy: 0.0000e+00 - val_loss: 10672658.0000 - val_accuracy: 0.0000e+00
# Epoch 161/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1854800.5000 - accuracy: 0.0000e+00 - val_loss: 11017175.0000 - val_accuracy: 0.0000e+00
# Epoch 162/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1888895.8750 - accuracy: 0.0000e+00 - val_loss: 11327178.0000 - val_accuracy: 0.0000e+00
# Epoch 163/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1935109.0000 - accuracy: 0.0000e+00 - val_loss: 11686873.0000 - val_accuracy: 0.0000e+00
# Epoch 164/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1966570.3750 - accuracy: 0.0000e+00 - val_loss: 11794811.0000 - val_accuracy: 0.0000e+00
# Epoch 165/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2000034.8750 - accuracy: 0.0000e+00 - val_loss: 12436364.0000 - val_accuracy: 0.0000e+00
# Epoch 166/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2075041.6250 - accuracy: 0.0000e+00 - val_loss: 12415308.0000 - val_accuracy: 0.0000e+00
# Epoch 167/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2068872.8750 - accuracy: 0.0000e+00 - val_loss: 12469043.0000 - val_accuracy: 0.0000e+00
# Epoch 168/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2090737.5000 - accuracy: 0.0000e+00 - val_loss: 13033397.0000 - val_accuracy: 0.0000e+00
# Epoch 169/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2237431.5000 - accuracy: 0.0000e+00 - val_loss: 16133685.0000 - val_accuracy: 0.0000e+00
# Epoch 170/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2487316.0000 - accuracy: 0.0000e+00 - val_loss: 12283586.0000 - val_accuracy: 0.0000e+00
# Epoch 171/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2073825.1250 - accuracy: 0.0000e+00 - val_loss: 11348811.0000 - val_accuracy: 0.0000e+00
# Epoch 172/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1983802.0000 - accuracy: 0.0000e+00 - val_loss: 10637711.0000 - val_accuracy: 0.0000e+00
# Epoch 173/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1916226.6250 - accuracy: 0.0000e+00 - val_loss: 10517923.0000 - val_accuracy: 0.0000e+00
# Epoch 174/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1913136.0000 - accuracy: 0.0000e+00 - val_loss: 10321501.0000 - val_accuracy: 0.0000e+00
# Epoch 175/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1900995.7500 - accuracy: 0.0000e+00 - val_loss: 10377933.0000 - val_accuracy: 0.0000e+00
# Epoch 176/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1902765.1250 - accuracy: 0.0000e+00 - val_loss: 10111139.0000 - val_accuracy: 0.0000e+00
# Epoch 177/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1849172.8750 - accuracy: 0.0000e+00 - val_loss: 9682808.0000 - val_accuracy: 0.0000e+00
# Epoch 178/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1799607.5000 - accuracy: 0.0000e+00 - val_loss: 10016681.0000 - val_accuracy: 0.0000e+00
# Epoch 179/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1860458.0000 - accuracy: 0.0000e+00 - val_loss: 11301421.0000 - val_accuracy: 0.0000e+00
# Epoch 180/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1962638.0000 - accuracy: 0.0000e+00 - val_loss: 9285956.0000 - val_accuracy: 0.0000e+00
# Epoch 181/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1702811.3750 - accuracy: 0.0000e+00 - val_loss: 9356319.0000 - val_accuracy: 0.0000e+00
# Epoch 182/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1764246.6250 - accuracy: 0.0000e+00 - val_loss: 12294420.0000 - val_accuracy: 0.0000e+00
# Epoch 183/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1929148.3750 - accuracy: 0.0000e+00 - val_loss: 8861646.0000 - val_accuracy: 0.0000e+00
# Epoch 184/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1585902.3750 - accuracy: 0.0000e+00 - val_loss: 9010994.0000 - val_accuracy: 0.0000e+00
# Epoch 185/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1618177.2500 - accuracy: 0.0000e+00 - val_loss: 8728787.0000 - val_accuracy: 0.0000e+00
# Epoch 186/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1583607.1250 - accuracy: 0.0000e+00 - val_loss: 9091387.0000 - val_accuracy: 0.0000e+00
# Epoch 187/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1607986.3750 - accuracy: 0.0000e+00 - val_loss: 9319647.0000 - val_accuracy: 0.0000e+00
# Epoch 188/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1636344.5000 - accuracy: 0.0000e+00 - val_loss: 9993073.0000 - val_accuracy: 0.0000e+00
# Epoch 189/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1703775.0000 - accuracy: 0.0000e+00 - val_loss: 10274994.0000 - val_accuracy: 0.0000e+00
# Epoch 190/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1729156.3750 - accuracy: 0.0000e+00 - val_loss: 10688907.0000 - val_accuracy: 0.0000e+00
# Epoch 191/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1768050.6250 - accuracy: 0.0000e+00 - val_loss: 10930800.0000 - val_accuracy: 0.0000e+00
# Epoch 192/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1796481.2500 - accuracy: 0.0000e+00 - val_loss: 11630532.0000 - val_accuracy: 0.0000e+00
# Epoch 193/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1845502.6250 - accuracy: 0.0000e+00 - val_loss: 11762641.0000 - val_accuracy: 0.0000e+00
# Epoch 194/200
# 20/20 [==============================] - 0s 2ms/step - loss: 1892359.6250 - accuracy: 0.0000e+00 - val_loss: 12188335.0000 - val_accuracy: 0.0000e+00
# Epoch 195/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1933421.3750 - accuracy: 0.0000e+00 - val_loss: 12556507.0000 - val_accuracy: 0.0000e+00
# Epoch 196/200
# 20/20 [==============================] - 0s 1ms/step - loss: 1979726.7500 - accuracy: 0.0000e+00 - val_loss: 12710993.0000 - val_accuracy: 0.0000e+00
# Epoch 197/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2023512.1250 - accuracy: 0.0000e+00 - val_loss: 13025210.0000 - val_accuracy: 0.0000e+00
# Epoch 198/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2044869.3750 - accuracy: 0.0000e+00 - val_loss: 12571456.0000 - val_accuracy: 0.0000e+00
# Epoch 199/200
# 20/20 [==============================] - 0s 1ms/step - loss: 2047574.1250 - accuracy: 0.0000e+00 - val_loss: 12668568.0000 - val_accuracy: 0.0000e+00
# Epoch 200/200
# 20/20 [==============================] - 0s 2ms/step - loss: 2071567.6250 - accuracy: 0.0000e+00 - val_loss: 12193862.0000 - val_accuracy: 0.0000e+00

# %%
y_predicted = network.predict(X_test, verbose=1)
result = test_data.iloc[window_size:]
result['Predicted'] = y_predicted
result[['Close','Predicted']]
# Out:
# 11/11 [==============================] - 0s 539us/step
# <ipython-input-80-f75e88b767c6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['Predicted'] = y_predicted
#                    Close     Predicted
# Date
# 2022-05-18  28720.271484  27758.273438
# 2022-05-19  30314.333984  27368.837891
# 2022-05-20  29200.740234  27163.312500
# 2022-05-21  29432.226563  27626.718750
# 2022-05-22  30323.722656  26835.203125
# ...                  ...           ...
# 2023-04-28  29340.261719  27038.957031
# 2023-04-29  29248.488281  27245.228516
# 2023-04-30  29268.806641  27400.863281
# 2023-05-01  28091.568359  27884.730469
# 2023-05-02  28676.791016  27002.214844
#
# [350 rows x 2 columns]

# %%
test_set_range = result.index
plt.figure(figsize=(20,9))
plt.plot(test_set_range, result['Predicted'], color='blue', marker='o', linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range, result['Close'], color='red', label='Actual Price')
plt.title('BTC Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

MSE = mean_squared_error(result['Close'], result['Predicted'])
RMSE = mean_squared_error(result['Close'], result['Predicted'], squared=False)
MAE = mean_absolute_error(result['Close'], result['Predicted'])
R2 = r2_score(result['Close'], result['Predicted'])

print('MSE:', mse)
print('RMSE:', rmse)
print('MAE:', mae)
print('R2:', r2)
# Out:
# MSE: 4298838.696673542
# RMSE: 2073.3641013274882
# MAE: 1559.8625067054597
# R2: 0.754566799830918

# %%
import pandas as pd

# Değerleri bir sözlük yapısında sakla
results = {'MSE': [MSE], 'RMSE': [RMSE], 'MAE': [MAE], 'R2': [R2]}

# DataFrame oluştur ve index değerlerini varsayılan değerlerle ata
MLP_ERROR= pd.DataFrame.from_dict(results, orient='index').T

# DataFrame'i ERROR ismiyle kaydet
MLP_ERROR = MLP_ERROR.to_string(index=False)

# ERROR'u yazdır

print(MLP_ERROR)
# Out:
#          MSE        RMSE         MAE       R2
# 2.715959e+06 1648.016588 1460.566791 0.842159
